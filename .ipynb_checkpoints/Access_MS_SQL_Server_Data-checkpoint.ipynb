# %% [markdown]
# ## Basic library imports

# %%
import pandas as pd
import numpy as np
import mssql_python
import pyodbc
import urllib
from sqlalchemy import create_engine

# %% [markdown]
# ## Establish the database connections with SQL Server
# The recommended workflow is to make your data tables in Microsoft SQL Server and then simply access the joined/filtered outputs here. Trying to query the full datasets in Python is likely to create memory timeouts, depending on how much data you're trying to pull back. Creating and saving the desired manipulate in SQL Server also enables others to more easily access your data products.

# %%
# establish the connection parameters
odbc_str = ("DRIVER={ODBC Driver 18 for SQL Server};"
            "SERVER=VHACDWA01.vha.med.va.gov,1433;"
            "DATABASE=OPCCCT_Analytics;"
            "Trusted_Connection=yes;"
            "Encrypt=yes;"
            "TrustServerCertificate=no;")

# URL-encode it so SQLAlchemy can parse it correctly
params = urllib.parse.quote_plus(odbc_str)
engine = create_engine(f"mssql+pyodbc:///?odbc_connect={params}")

# read in the data
df = pd.read_sql("SELECT TOP 1000 * FROM [OPCCCT_Analytics].[DOEx].[WholeHealth_1_VISITS]", engine)

# %%
df
# Out:
#      TableId      VisitSID       VisitDateTime LastModifiedDateTime  \
# 0          1  800469805403 2015-10-02 14:00:00           2015-10-05
# 1          2  800469805421 2015-10-02 14:00:00           2015-10-05
# 2          3  800469805434 2015-10-02 14:00:00           2015-10-05
# 3          4  800469805646 2015-10-02 13:00:00           2015-10-02
# 4          5  800469805676 2015-10-02 13:00:00           2015-10-02
# ..       ...           ...                 ...                  ...
# 995      999  800471989152 2015-10-20 12:00:00           2015-10-21
# 996     1000  800471989229 2015-10-20 09:00:00           2015-10-20
# 997     1001  800471989305 2015-10-20 09:00:00           2015-10-20
# 998     1002  800471989313 2015-10-20 09:00:00           2015-10-20
# 999     1003  800471989322 2015-10-20 09:00:00           2015-10-20
#
#     NoncountClinicFlag EncounterType PatientStatusInOut AppointmentStatus  \
# 0                    N             P                  0       CHECKED OUT
# 1                    N             P                  0       CHECKED OUT
# 2                    N             P                  0       CHECKED OUT
# 3                    N             P                  0       CHECKED OUT
# 4                    N             P                  0       CHECKED OUT
# ..                 ...           ...                ...               ...
# 995                  N             P                  0       CHECKED OUT
# 996                  N             P                  0       CHECKED OUT
# 997                  N             P                  0       CHECKED OUT
# 998                  N             P                  0       CHECKED OUT
# 999                  N             P                  0       CHECKED OUT
#
#        AppointmentType  Sta3n  ... SrcCHAR4 SrcArcCPT1 SrcArcCPT2  SrcArcCPT3  \
# 0    SERVICE CONNECTED    612  ...      1.0        NaN        NaN         NaN
# 1              REGULAR    612  ...      1.0        NaN        NaN         NaN
# 2              REGULAR    612  ...      1.0        NaN        NaN         NaN
# 3              REGULAR    612  ...      NaN        NaN        NaN         1.0
# 4              REGULAR    612  ...      NaN        NaN        NaN         1.0
# ..                 ...    ...  ...      ...        ...        ...         ...
# 995            REGULAR    436  ...      NaN        NaN        1.0         1.0
# 996            REGULAR    436  ...      NaN        NaN        NaN         NaN
# 997            REGULAR    436  ...      NaN        NaN        NaN         NaN
# 998            REGULAR    436  ...      NaN        NaN        NaN         NaN
# 999            REGULAR    436  ...      NaN        NaN        NaN         NaN
#
#     SrcHF SrcMOVE1 SrcMOVE2 SrcSTOP1 SrcSTOP2            LoadDate
# 0    None      NaN      NaN      NaN      NaN 2024-08-12 20:48:15
# 1    None      NaN      NaN      NaN      NaN 2024-08-12 20:48:15
# 2    None      NaN      NaN      NaN      NaN 2024-08-12 20:48:15
# 3    None      NaN      1.0      NaN      1.0 2024-08-12 20:48:15
# 4    None      NaN      1.0      NaN      1.0 2024-08-12 20:48:15
# ..    ...      ...      ...      ...      ...                 ...
# 995  None      NaN      NaN      NaN      NaN 2024-08-12 20:48:15
# 996  None      1.0      NaN      1.0      NaN 2024-08-12 20:48:15
# 997  None      1.0      NaN      1.0      NaN 2024-08-12 20:48:15
# 998  None      1.0      NaN      1.0      NaN 2024-08-12 20:48:15
# 999  None      1.0      NaN      1.0      NaN 2024-08-12 20:48:15
#
# [1000 rows x 44 columns]
